# %%
import random
class PhishingAttack:
    def __init__(self, victim_name):
        self.victim_name = victim_name

    def send_email(self):
        sender_name = "Your Bank"
        sender_email = "bank@example.com"
        subject = "Urgent: Security Alert"
        body = (
            f"Dear {self.victim_name},\n\n"
            "We have noticed some suspicious activity on your account. "
            "Please click on the following link to verify your identity:\n\n"
            f"http://maliciouswebsite.com/verify?id={random.randint(1000,9999)}\n\n"
            f"Thank you,\n{sender_name}"
        )

        # Send the email (in a real scenario, you would use an email library like smtplib)
        print("Phishing email sent to:", self.victim_name)
        print("From:", sender_name)
        print("Subject:", subject)
        print("Body:", body)

    def run_attack(self):
        self.send_email()
        # Here you could add more steps like setting up a fake login page to steal credentials,
        # but for simplicity, let's assume the victim clicks the link and provides their information.


# Example usage
victim_name = input("Enter victim's name: ")
phishing_attack = PhishingAttack(victim_name)
phishing_attack.run_attack()
# Out:
# Enter victim's name:  jayesh
# Phishing email sent to: jayesh
# From: Your Bank
# Subject: Urgent: Security Alert
# Body: Dear jayesh,
#
# We have noticed some suspicious activity on your account. Please click on the following link to verify your identity:
#
# http://maliciouswebsite.com/verify?id=5421
#
# Thank you,
# Your Bank
